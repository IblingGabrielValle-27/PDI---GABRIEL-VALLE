# %% [markdown]
# convolucion

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

img = cv2.imread('image.png',0)
mascara =np.array([[0,-1,0],[-1,5,1],[0,-1,0]])#kernel
imgfin=cv2.filter2D(img,-1,mascara)
plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.subplot(122)
plt.imshow(imgfin, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

img = cv2.imread('image.png',0)
kernel5x5 = np.ones((5,5),np.float32)/25 #suavizado
suavizado = cv2.filter2D(img,-1,kernel5x5)#imagen suavizada

kernel7x7 = np.ones((7,7),np.float32)/49

suavizado2 = cv2.filter2D(img,-1,kernel7x7)

plt.figure(figsize=(10,10))
plt.subplot(141)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.subplot(142)
plt.imshow(img,cmap='gray')
plt.subplot(143)
plt.imshow(suavizado,cmap='gray')
plt.subplot(144)
plt.imshow(suavizado2,cmap='gray')

# %% [markdown]
# convolucion con matriz 1xn

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convolucionmediohorizontal(imagen,tamanioKernel):
    kernel= np.ones((1,tamanioKernel),np.float32)/tamanioKernel
    imgfin= cv2.filter2D(imagen,-1,kernel)
    return imgfin
imagen= cv2.imread('img.jpeg')
gris= cv2.cvtColor(imagen,cv2.COLOR_BGR2GRAY)

imgrest= convolucionmediohorizontal(gris,9)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.imshow(imgrest,cmap='gray')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convolucionmediohorizontal(imagen,tamanioKernel):
    kernel= np.ones((1,tamanioKernel),np.float32)/tamanioKernel
    imgfin= cv2.filter2D(imagen,-1,kernel)
    return imgfin
imagen= cv2.imread('img.jpeg')
imgrgb= cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

imgrestr= convolucionmediohorizontal(imgrgb[:,:,0],25)
imgrestg= convolucionmediohorizontal(imgrgb[:,:,1],25)
imgrestb= convolucionmediohorizontal(imgrgb[:,:,2],25)

imgcolor=np.stack([imgrestr,imgrestg,imgrestb],axis=2)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(imgrgb)

plt.subplot(122)
plt.imshow(imgcolor)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# mejorar ej

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convolucion_medio_horizontal(imagen,tamanioKernel):
    kernel= np.ones((1,tamanioKernel),np.float32)/tamanioKernel
    imgfin= cv2.filter2D(imagen,-1,kernel)
    return imgfin
imagen= cv2.imread('img1.jpeg')
imgrgb= cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

imgrestr= convolucion_medio_horizontal(imgrgb[:,:,0],5)
imgrestg= convolucion_medio_horizontal(imgrgb[:,:,1],5)
imgrestb= convolucion_medio_horizontal(imgrgb[:,:,2],5)

imgcolor=np.stack([imgrestr,imgrestg,imgrestb],axis=2)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(imgrgb)

plt.subplot(122)
plt.imshow(imgcolor)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import cv2
import numpy as plt
import matplotlib.pyplot as plt
img_ruido= np.random.randint(0,256,size=(256,256),dtype=np.uint8)
img_blur=cv2.GaussianBlur(img_ruido,(5,5),0)
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(img_ruido,cmap='gray')

plt.subplot(122)
plt.imshow(img_blur,cmap='gray')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convolucion_medio_vertical(imagen, tamanioKernel):
    kernel = np.ones((tamanioKernel, 1), np.float32) / tamanioKernel
    imgfin = cv2.filter2D(imagen, -1, kernel)
    return imgfin

imagen= cv2.imread('img2.png')
imgrgb= cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

imgrestr = convolucion_medio_vertical(imgrgb[:, :, 0], 25)
imgrestg = convolucion_medio_vertical(imgrgb[:, :, 1], 25)
imgrestb = convolucion_medio_vertical(imgrgb[:, :, 2], 25)

imgcolor = np.stack([imgrestr, imgrestg, imgrestb], axis=2)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(imgrgb)
plt.title("Original")

plt.subplot(122)
plt.imshow(imgcolor)
plt.title("Convolución Vertical")

plt.show()
